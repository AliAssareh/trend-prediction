# %%
from ModelingUtils.trainers import MixCwdn, AuxiliaryNet

# %% [markdown]
# # MIX 4h

# %% [markdown]
# ## train conv net of each input along with pretrained btcusdt input

# %% [markdown]
# ### train btcusdt conv_net

# %%
a_net0 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=0, suffix=1, batch_size=127, max_epochs=50)
# Out:
# cuda
# (4178, 1, 1)
# (1418, 1, 1)
# (960, 1, 1)

# %%
a_net0.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net0.train_model(lr=16e-4, weight_decay=1e-3, patience=5, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0061474 	 total_test 0.0061369 	 execution time: 43
#
#  EPOCH 2/50 	 total_train 0.0057361 	 total_test 0.0057597 	 execution time: 42
#
#  EPOCH 3/50 	 total_train 0.0055846 	 total_test 0.0060440 	 execution time: 42
#
#  EPOCH 4/50 	 total_train 0.0055770 	 total_test 0.0057535 	 execution time: 43
#
#  EPOCH 5/50 	 total_train 0.0054890 	 total_test 0.0056449 	 execution time: 42
#
#  EPOCH 6/50 	 total_train 0.0055009 	 total_test 0.0055959 	 execution time: 42
#
#  EPOCH 7/50 	 total_train 0.0054892 	 total_test 0.0055520 	 execution time: 42
#
#  EPOCH 8/50 	 total_train 0.0054444 	 total_test 0.0055723 	 execution time: 42
#
#  EPOCH 9/50 	 total_train 0.0054296 	 total_test 0.0056253 	 execution time: 42
#
#  EPOCH 10/50 	 total_train 0.0053888 	 total_test 0.0055762 	 execution time: 42
#
#  EPOCH 11/50 	 total_train 0.0052773 	 total_test 0.0057835 	 execution time: 42
#
# ...

# %%
a_net0.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4912/4912 [01:19<00:00, 61.89it/s]
# accuracy: 0.7463355048859935
# f_score_rise: 0.7778966131907308, precision_rise: 0.7409168081494057, recall_rise: 0.8187617260787993
# f_score_fall: 0.7043189368770765, precision_fall: 0.7544483985765125, recall_fall: 0.660436137071651
# 100%|████████████████████████████████████████████████████████████████████████████████| 978/978 [00:15<00:00, 64.12it/s]
# accuracy: 0.7361963190184049
# f_score_rise: 0.7485380116959065, precision_rise: 0.7272727272727273, recall_rise: 0.7710843373493976
# f_score_fall: 0.7225806451612902, precision_fall: 0.7466666666666667, recall_fall: 0.7
# 100%|████████████████████████████████████████████████████████████████████████████████| 666/666 [00:10<00:00, 64.38it/s]
# accuracy: 0.7102102102102102
# f_score_rise: 0.7123695976154992, precision_rise: 0.7155688622754491, recall_rise: 0.7091988130563798
# ...

# %%
a_net0.save_conv_net()

# %% [markdown]
# ### train BTCD conv_net

# %%
a_net1 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=1, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net1.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net1.train_model(lr=16e-4, weight_decay=5e-4, patience=1, just_load=False)
# Out:
#  EPOCH 1/50 	 total_train 0.0036859 	 total_test 0.0041273 	 execution time: 48
#
#  EPOCH 2/50 	 total_train 0.0033294 	 total_test 0.0034747 	 execution time: 48
#
#  EPOCH 3/50 	 total_train 0.0031542 	 total_test 0.0032658 	 execution time: 48
#
#  EPOCH 4/50 	 total_train 0.0030279 	 total_test 0.0030462 	 execution time: 48
#
#  EPOCH 5/50 	 total_train 0.0029454 	 total_test 0.0030387 	 execution time: 48
#
#  EPOCH 6/50 	 total_train 0.0028638 	 total_test 0.0029963 	 execution time: 48
#
#  EPOCH 7/50 	 total_train 0.0028579 	 total_test 0.0030121 	 execution time: 48

# %%
a_net1.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:05<00:00, 63.66it/s]
# accuracy: 0.7276208712302538
# f_score_rise: 0.7685109845402768, precision_rise: 0.70537714712472, recall_rise: 0.8440571939231457
# f_score_fall: 0.6691860465116278, precision_fall: 0.7673333333333333, recall_fall: 0.593298969072165
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 63.99it/s]
# accuracy: 0.736953455571227
# f_score_rise: 0.7579493835171965, precision_rise: 0.7545219638242894, recall_rise: 0.7614080834419817
# f_score_fall: 0.711969111969112, precision_fall: 0.7158385093167702, recall_fall: 0.7081413210445469
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:15<00:00, 64.00it/s]
# accuracy: 0.71875
# f_score_rise: 0.7090517241379309, precision_rise: 0.7598152424942263, recall_rise: 0.6646464646464646
# ...

# %%
a_net1.save_conv_net()

# %% [markdown]
# ### train Total conv_net

# %%
a_net2 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=2, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net2.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net2.train_model(lr=16e-4, weight_decay=5e-4, patience=3, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0032338 	 total_test 0.0040222 	 execution time: 47
#
#  EPOCH 2/50 	 total_train 0.0029183 	 total_test 0.0037394 	 execution time: 48
#
#  EPOCH 3/50 	 total_train 0.0028971 	 total_test 0.0039305 	 execution time: 48
#
#  EPOCH 4/50 	 total_train 0.0028388 	 total_test 0.0029211 	 execution time: 48
#
#  EPOCH 5/50 	 total_train 0.0028024 	 total_test 0.0030063 	 execution time: 48
#
#  EPOCH 6/50 	 total_train 0.0028119 	 total_test 0.0032388 	 execution time: 48
#
#  EPOCH 7/50 	 total_train 0.0027347 	 total_test 0.0031043 	 execution time: 48

# %%
a_net2.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:05<00:00, 63.70it/s]
# accuracy: 0.7247486835806606
# f_score_rise: 0.7720967102655569, precision_rise: 0.6937321937321937, recall_rise: 0.870420017873101
# f_score_fall: 0.6525679758308157, precision_fall: 0.7883211678832117, recall_fall: 0.5567010309278351
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 64.24it/s]
# accuracy: 0.7390691114245416
# f_score_rise: 0.7634271099744244, precision_rise: 0.7490589711417817, recall_rise: 0.7783572359843546
# f_score_fall: 0.7091194968553458, precision_fall: 0.7262479871175523, recall_fall: 0.6927803379416283
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:15<00:00, 63.62it/s]
# accuracy: 0.7239583333333334
# f_score_rise: 0.7097480832420592, precision_rise: 0.7751196172248804, recall_rise: 0.6545454545454545
# ...

# %%
a_net2.save_conv_net()

# %% [markdown]
# ### train usdtd conv_net

# %%
a_net3 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=3, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net3.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net3.train_model(lr=16e-4, weight_decay=5e-4, patience=1, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0041881 	 total_test 0.0044096 	 execution time: 46
#
#  EPOCH 2/50 	 total_train 0.0037855 	 total_test 0.0040165 	 execution time: 47
#
#  EPOCH 3/50 	 total_train 0.0036117 	 total_test 0.0031862 	 execution time: 47
#
#  EPOCH 4/50 	 total_train 0.0034196 	 total_test 0.0031285 	 execution time: 48
#
#  EPOCH 5/50 	 total_train 0.0032632 	 total_test 0.0032386 	 execution time: 48

# %%
a_net3.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:05<00:00, 63.57it/s]
# accuracy: 0.6969842029679273
# f_score_rise: 0.7675358060962174, precision_rise: 0.6514962593516209, recall_rise: 0.9338695263628239
# f_score_fall: 0.5649484536082474, precision_fall: 0.8474226804123711, recall_fall: 0.42371134020618556
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 64.39it/s]
# accuracy: 0.7179125528913963
# f_score_rise: 0.7701149425287357, precision_rise: 0.6885919835560124, recall_rise: 0.8735332464146024
# f_score_fall: 0.6350364963503651, precision_fall: 0.7820224719101123, recall_fall: 0.5345622119815668
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:14<00:00, 64.12it/s]
# accuracy: 0.725
# f_score_rise: 0.7495256166982922, precision_rise: 0.7066189624329159, recall_rise: 0.797979797979798
# ...

# %%
a_net3.save_conv_net()

# %% [markdown]
# ### train dxy conv_net

# %%
a_net4 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=4, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net4.generate_model(seed=1)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net4.train_model(lr=16e-4, weight_decay=5e-4, patience=3, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0036012 	 total_test 0.0039019 	 execution time: 35
#
#  EPOCH 2/50 	 total_train 0.0033639 	 total_test 0.0034029 	 execution time: 36
#
#  EPOCH 3/50 	 total_train 0.0032203 	 total_test 0.0031691 	 execution time: 36
#
#  EPOCH 4/50 	 total_train 0.0030908 	 total_test 0.0030815 	 execution time: 36
#
#  EPOCH 5/50 	 total_train 0.0029698 	 total_test 0.0029735 	 execution time: 36
#
#  EPOCH 6/50 	 total_train 0.0028872 	 total_test 0.0029350 	 execution time: 36
#
#  EPOCH 7/50 	 total_train 0.0028534 	 total_test 0.0028807 	 execution time: 36
#
#  EPOCH 8/50 	 total_train 0.0028234 	 total_test 0.0029967 	 execution time: 36
#
#  EPOCH 9/50 	 total_train 0.0027856 	 total_test 0.0028818 	 execution time: 37
#
#  EPOCH 10/50 	 total_train 0.0027639 	 total_test 0.0030044 	 execution time: 36

# %%
a_net4.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:01<00:00, 67.68it/s]
# accuracy: 0.734561991383437
# f_score_rise: 0.7760952957803352, precision_rise: 0.7079189686924493, recall_rise: 0.8588025022341377
# f_score_fall: 0.6741110784601821, precision_fall: 0.7840054682159945, recall_fall: 0.5912371134020619
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:20<00:00, 68.06it/s]
# accuracy: 0.736953455571227
# f_score_rise: 0.7591994835377662, precision_rise: 0.7519181585677749, recall_rise: 0.7666232073011734
# f_score_fall: 0.7101787101787101, precision_fall: 0.7185534591194969, recall_fall: 0.7019969278033794
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:14<00:00, 67.78it/s]
# accuracy: 0.71875
# f_score_rise: 0.7006651884700664, precision_rise: 0.7764127764127764, recall_rise: 0.6383838383838384
# ...

# %%
a_net4.save_conv_net()

# %% [markdown]
# ### train gold conv_net

# %%
a_net5 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=5, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net5.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net5.train_model(lr=16e-4, weight_decay=5e-4, patience=3, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0032642 	 total_test 0.0040094 	 execution time: 47
#
#  EPOCH 2/50 	 total_train 0.0029189 	 total_test 0.0036675 	 execution time: 48
#
#  EPOCH 3/50 	 total_train 0.0028937 	 total_test 0.0038955 	 execution time: 48
#
#  EPOCH 4/50 	 total_train 0.0028669 	 total_test 0.0029488 	 execution time: 48
#
#  EPOCH 5/50 	 total_train 0.0028500 	 total_test 0.0029397 	 execution time: 48
#
#  EPOCH 6/50 	 total_train 0.0028521 	 total_test 0.0032713 	 execution time: 48
#
#  EPOCH 7/50 	 total_train 0.0027975 	 total_test 0.0028836 	 execution time: 48
#
#  EPOCH 8/50 	 total_train 0.0027946 	 total_test 0.0033011 	 execution time: 48
#
#  EPOCH 9/50 	 total_train 0.0027827 	 total_test 0.0031617 	 execution time: 48
#
#  EPOCH 10/50 	 total_train 0.0027489 	 total_test 0.0030344 	 execution time: 48

# %%
a_net5.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:05<00:00, 63.83it/s]
# accuracy: 0.7403063666826233
# f_score_rise: 0.7791573376755547, precision_rise: 0.7155140186915888, recall_rise: 0.8552278820375335
# f_score_fall: 0.6848678478071449, precision_fall: 0.7844311377245509, recall_fall: 0.6077319587628865
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 63.91it/s]
# accuracy: 0.7489421720733427
# f_score_rise: 0.7654808959156785, precision_rise: 0.7736351531291611, recall_rise: 0.757496740547588
# f_score_fall: 0.7298937784522002, precision_fall: 0.7211394302848576, recall_fall: 0.738863287250384
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:15<00:00, 63.92it/s]
# accuracy: 0.7166666666666667
# f_score_rise: 0.695067264573991, precision_rise: 0.7808564231738035, recall_rise: 0.6262626262626263
# ...

# %%
a_net5.save_conv_net()

# %% [markdown]
# ### train spx conv_net

# %%
a_net6 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=6, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net6.generate_model(seed=1)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net6.train_model(lr=16e-4, weight_decay=5e-4, patience=2, just_load=True)
# Out:
#  EPOCH 1/50 	 total_train 0.0036220 	 total_test 0.0040944 	 execution time: 46
#
#  EPOCH 2/50 	 total_train 0.0032037 	 total_test 0.0031787 	 execution time: 46
#
#  EPOCH 3/50 	 total_train 0.0030601 	 total_test 0.0030971 	 execution time: 46
#
#  EPOCH 4/50 	 total_train 0.0029403 	 total_test 0.0029918 	 execution time: 46
#
#  EPOCH 5/50 	 total_train 0.0028824 	 total_test 0.0032580 	 execution time: 46
#
#  EPOCH 6/50 	 total_train 0.0028518 	 total_test 0.0029797 	 execution time: 46
#
#  EPOCH 7/50 	 total_train 0.0027939 	 total_test 0.0029367 	 execution time: 46
#
#  EPOCH 8/50 	 total_train 0.0027892 	 total_test 0.0030696 	 execution time: 46
#
#  EPOCH 9/50 	 total_train 0.0027671 	 total_test 0.0030404 	 execution time: 46

# %%
a_net6.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:05<00:00, 63.37it/s]
# accuracy: 0.7503590234561991
# f_score_rise: 0.7743889249405148, precision_rise: 0.750524109014675, recall_rise: 0.7998212689901698
# f_score_fall: 0.7206000535762122, precision_fall: 0.7501394311210262, recall_fall: 0.6932989690721649
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 63.57it/s]
# accuracy: 0.7433004231311706
# f_score_rise: 0.7543859649122807, precision_rise: 0.7818181818181819, recall_rise: 0.7288135593220338
# f_score_fall: 0.7311669128508125, precision_fall: 0.7041251778093883, recall_fall: 0.7603686635944701
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:15<00:00, 63.86it/s]
# accuracy: 0.7010416666666667
# f_score_rise: 0.6537997587454765, precision_rise: 0.811377245508982, recall_rise: 0.5474747474747474
# ...

# %%
a_net6.save_conv_net()

# %% [markdown]
# ### train ukoil conv_net

# %%
a_net7 = AuxiliaryNet('mix_4h_for_target1_1', 'target1', net_code=7, suffix=1, batch_size=254, max_epochs=50)
# Out:
# cuda

# %%
a_net7.generate_model(seed=0)
# Out:
# btc_conv_net weights frozen
# AuxiliaryMixedConvWideDeepLSTMNet(
#   (conv_net): AuxiliaryMixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
#       (batch3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv3d(1, 1, kernel_size=(64, 1, 1), stride=(1, 1, 1))
# ...

# %%
a_net7.train_model(lr=16e-4, weight_decay=5e-4, patience=3, just_load=False)
# Out:
#  EPOCH 1/50 	 total_train 0.0042000 	 total_test 0.0046885 	 execution time: 47
#
#  EPOCH 2/50 	 total_train 0.0037976 	 total_test 0.0040797 	 execution time: 47
#
#  EPOCH 3/50 	 total_train 0.0036114 	 total_test 0.0032829 	 execution time: 48
#
#  EPOCH 4/50 	 total_train 0.0034739 	 total_test 0.0031369 	 execution time: 48
#
#  EPOCH 5/50 	 total_train 0.0033294 	 total_test 0.0029387 	 execution time: 48
#
#  EPOCH 6/50 	 total_train 0.0032048 	 total_test 0.0029378 	 execution time: 48
#
#  EPOCH 7/50 	 total_train 0.0031119 	 total_test 0.0030822 	 execution time: 48
#
#  EPOCH 8/50 	 total_train 0.0029974 	 total_test 0.0030142 	 execution time: 48
#
#  EPOCH 9/50 	 total_train 0.0029349 	 total_test 0.0033639 	 execution time: 48

# %%
a_net7.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [01:06<00:00, 63.19it/s]
# accuracy: 0.7223551938726663
# f_score_rise: 0.7751937984496123, precision_rise: 0.6844626967830253, recall_rise: 0.8936550491510277
# f_score_fall: 0.6370463078848561, precision_fall: 0.8105095541401274, recall_fall: 0.5247422680412371
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:22<00:00, 63.80it/s]
# accuracy: 0.731311706629055
# f_score_rise: 0.7617260787992496, precision_rise: 0.7319711538461539, recall_rise: 0.7940026075619296
# f_score_fall: 0.6919967663702506, precision_fall: 0.7303754266211604, recall_fall: 0.6574500768049155
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:15<00:00, 63.77it/s]
# accuracy: 0.7260416666666667
# f_score_rise: 0.7187165775401071, precision_rise: 0.7636363636363637, recall_rise: 0.6787878787878788
# ...

# %%
a_net7.save_conv_net()

# %% [markdown]
# ## Mix the inputs and use pretrained conv_nets to generate the mixed data results

# %%
cwdn = MixCwdn('mix_4h_for_target1_1', 'target1', suffix=1, batch_size=127, max_epochs=50)
# Out:
# cuda

# %%
cwdn.generate_model(seed=1)
# Out:
# btc_conv_net weights frozen
# btcd_conv_net weights frozen
# total_conv_net weights frozen
# usdt_conv_net weights frozen
# dxy_conv_net weights frozen
# gold_conv_net weights frozen
# spx_conv_net weights frozen
# ukoil_conv_net weights frozen
# MixedConvWideDeepLSTMNet(
#   (conv_net): MixedConvNet(
#     (btc): BTCConv(
#       (conv1): Conv2d(1, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 0))
#       (max1): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 0))
#       (max2): MaxPool2d(kernel_size=(1, 3), stride=(1, 1), padding=(0, 0), dilation=1, ceil_mode=False)
#       (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=(1, 0))
# ...

# %%
cwdn.train_model(lr=16e-4, weight_decay=5e-4, patience=2, w1=0.72, w2=0.28, just_load=False)
# Out:
#  EPOCH 1/50 	 total_train 0.0072856 	 total_test 0.0103459 	 execution time: 200
#
#  EPOCH 2/50 	 total_train 0.0062349 	 total_test 0.0128960 	 execution time: 199
#
#  EPOCH 3/50 	 total_train 0.0057652 	 total_test 0.0068737 	 execution time: 199
#
#  EPOCH 4/50 	 total_train 0.0053220 	 total_test 0.0061195 	 execution time: 199
#
#  EPOCH 5/50 	 total_train 0.0051300 	 total_test 0.0065519 	 execution time: 199
#
#  EPOCH 6/50 	 total_train 0.0050725 	 total_test 0.0073653 	 execution time: 199

# %%
cwdn.generate_results()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4178/4178 [02:48<00:00, 24.78it/s]
# accuracy: 0.755385351842987
# f_score_rise: 0.7929497568881685, precision_rise: 0.7253521126760564, recall_rise: 0.8744414655942806
# f_score_fall: 0.7011695906432748, precision_fall: 0.8101351351351351, recall_fall: 0.6180412371134021
# 100%|██████████████████████████████████████████████████████████████████████████████| 1418/1418 [00:57<00:00, 24.73it/s]
# accuracy: 0.7228490832157969
# f_score_rise: 0.7596330275229357, precision_rise: 0.7154377880184332, recall_rise: 0.8096479791395046
# f_score_fall: 0.6727726894254787, precision_fall: 0.7345454545454545, recall_fall: 0.620583717357911
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:38<00:00, 24.87it/s]
# accuracy: 0.69375
# f_score_rise: 0.7215909090909092, precision_rise: 0.679144385026738, recall_rise: 0.7696969696969697
# ...

# %%
accuracies = cwdn.generate_test_stats()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 960/960 [00:38<00:00, 24.75it/s]

# %% [markdown]
# ## VNCA

# %%
ae_fc = AeFc('mix_4h_for_target1_1', 'target1', 240, 1, batch_size=86, latent_dim=38, nca_dim=20, onca_c=3, kl_c=0.1, max_epochs=60)
# Out:
# cuda

# %%
ae_fc.train_auto_encoder(lr=16e-4, weight_decay=2e-3)
# Out:
#  EPOCH 1/60 	 total_train 21645.779 	 reconstruction loss 8689.060 	 onca 0.01762 	 kl 30.401
# 		 total_test 6052107604.758 	 reconstruction loss 2418147480.602 	 onca 0.01834 	 kl 49.158 	 execution time: 116s
#
#  EPOCH 2/60 	 total_train 12223.400 	 reconstruction loss 5244.409 	 onca 0.01550 	 kl 48.801
# 		 total_test 5861194918.641 	 reconstruction loss 2418151013.814 	 onca 0.01417 	 kl 66.346 	 execution time: 116s
#
#  EPOCH 3/60 	 total_train 9395.436 	 reconstruction loss 4319.965 	 onca 0.01371 	 kl 55.482
# 		 total_test 5841697702.648 	 reconstruction loss 2418148457.277 	 onca 0.01385 	 kl 35.382 	 execution time: 117s
#
#  EPOCH 4/60 	 total_train 7887.057 	 reconstruction loss 3698.685 	 onca 0.01344 	 kl 42.938
# 		 total_test 5828887626.219 	 reconstruction loss 2418139618.432 	 onca 0.01398 	 kl 35.950 	 execution time: 117s
#
#  EPOCH 5/60 	 total_train 6763.265 	 reconstruction loss 3229.734 	 onca 0.01294 	 kl 34.016
# ...

# %%
ae_fc.generate_fully_connected_network()

# %%
ae_fc.train_fully_connected_net()
# Out:
#  EPOCH 1/50 	 total_train 0.0109252 	 total_test 0.1165144 	 execution time: 37
#
#  EPOCH 2/50 	 total_train 0.0094278 	 total_test 0.3347416 	 execution time: 37
#
#  EPOCH 3/50 	 total_train 0.0090171 	 total_test 0.3614712 	 execution time: 37
#
#  EPOCH 4/50 	 total_train 0.0088773 	 total_test 0.4203454 	 execution time: 37

# %%
ae_fc.generate_results()

# %%
cwdn = Cwdn('mix_4h_for_target1_1', 'target1', 240, 1, batch_size=100, max_epochs=50)
# Out:
# cuda

# %%
cwdn.train_model(lr=16e-4, weight_decay=1e-3)
# Out:
#  EPOCH 1/50 	 total_train 0.0100963 	 total_test 0.0100141 	 execution time: 99
#
#  EPOCH 2/50 	 total_train 0.0091113 	 total_test 0.0093680 	 execution time: 97
#
#  EPOCH 3/50 	 total_train 0.0083409 	 total_test 0.0084161 	 execution time: 98
#
#  EPOCH 4/50 	 total_train 0.0079427 	 total_test 0.0085328 	 execution time: 98
#
#  EPOCH 5/50 	 total_train 0.0074659 	 total_test 0.0084046 	 execution time: 98
#
#  EPOCH 6/50 	 total_train 0.0072201 	 total_test 0.0083572 	 execution time: 98
#
#  EPOCH 7/50 	 total_train 0.0068693 	 total_test 0.0080958 	 execution time: 98
#
#  EPOCH 8/50 	 total_train 0.0065468 	 total_test 0.0082918 	 execution time: 98
#
#  EPOCH 9/50 	 total_train 0.0060636 	 total_test 0.0083190 	 execution time: 98
#
#  EPOCH 10/50 	 total_train 0.0058528 	 total_test 0.0083622 	 execution time: 98

# %%
ae_svm = AeSvm('mix_4h_for_target1_1', 'target1', 240, 1, batch_size=127, latent_dim=38, nca_dim=20, onca_c=3, kl_c=0.1)

# %%
ae_svm.generate_svm(kernel='rbf', c=1, gamma='scale')

# %%
ae_svm.train_svm()

# %%
ae_svm.generate_results()

# %%
ae_fc = AeFc('mix_1h_for_target1_1', 'target1', 60, 1, batch_size=127, latent_dim=38, nca_dim=20, onca_c=3, kl_c=0.1, max_epochs=60)

# %%
ae_fc.train_auto_encoder(lr=16e-4, weight_decay=2e-3)

# %%
ae_fc.train_fully_connected_net()

# %%
ae_fc.generate_results()
